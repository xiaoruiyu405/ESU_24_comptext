# %% [markdown]
# # Welcome to the Summer School Machine Learning for Digital Scholarly Editions September 21-25, 2026
#
# For the School we use a GitHub repository. Lecturers will use it to share materials with you.
#
# GitHub repo: https://github.com/DHGraz/dse-ml-2026/tree/main/materials
#
# To ensure you always have the latest version of the school materials, we will link your Google Drive with GitHub. This allows you to pull the latest version of the school materials into your Google Drive.

# %%
# import Google Drive
# this needs to be done every time you open a notebook that uses data from your Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# set drive/MyDrive/ ad base working directory
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# clone the summer school github repo
# !git clone https://github.com/DHGraz/dse-ml-2026.git
# Out:
# fatal: destination path 'dse-ml-2026' already exists and is not an empty directory.

# %%
# look at the content of the current working directory, you should now see the school directory dse-ml-2026
# %ls
# Out:
#  183943CA-F70F-4EDD-802F-D48C20E9569E.jpeg
#  2023社会网络分析.zip
# '2presidential_speeches_with_metadata (1).csv'
#  2presidential_speeches_with_metadata.csv
# 'Accident_inquests (1).csv'
#  Accident_inquests.csv
#  Accident_inquests.gsheet
# 'alumni_copy_fullname (1).csv'
# 'alumni_copy_fullname (2).csv'
#  alumni_copy_fullname.csv
#  alumni_copy_fullname.gsheet
# 'A Survey on Computational Literary Studies: Applications and Techniques.gdoc'
#  attendance.gsheet
#  baidu_pilot_results.csv
#  baidu_pilot_results.gsheet
# 'BARISTA JD responsibilities and expectations.gdoc'
# 'B.A. transcripts.pdf'
#  best_books_2020.csv
#  best_books_2020_genres.csv
#  best_books_2020_settings.csv
#  brave.gsheet
#  brave_pilot_person_summary.csv
# 'Can a Machine Understand Counterpoint.gdoc'
#  cheese_adjective_candidates.gsheet
# 'CIM 2023 Archives (Nov 2023).csv'
# 'CIM 2023 Artists workspaces (Nov 2023).csv'
# 'CIM 2023 Arts centres.csv'
# 'CIM 2023 Cinemas.csv'
# 'CIM 2023 Commercial galleries (Nov 2023).csv'
# 'CIM 2023 Creative coworking desk space.csv'
# 'CIM 2023 Creative workspaces (Nov 2023).csv'
# 'CIM 2023 Dance performance venues.csv'
# 'CIM 2023 Dance rehearsal studios.csv'
# 'CIM 2023 Fashion and design.csv'
# 'CIM 2023 Jewellery design (Nov 2023).csv'
# 'CIM 2023 Lgbt venues.csv'
# 'CIM 2023 Libraries (Nov 2023).csv'
# 'CIM 2023 Libraries (Nov 2023).gsheet'
# 'CIM 2023 Makerspaces (Nov 2023).csv'
# 'CIM 2023 Making and manufacturing.csv'
# 'CIM 2023 Museums and public galleries (Nov 2023).csv'
# 'CIM 2023 Music recording studios (Nov 2023).csv'
# 'CIM 2023 Music rehearsal studios (Nov 2023).csv'
# 'CIM 2023 Prop and costume making (1).csv'
# 'CIM 2023 Prop and costume making.csv'
# 'CIM 2023 Prop and costume making.gsheet'
# 'CIM 2023 Set and exhibition building.csv'
# 'CIM 2023 Textile design.csv'
# 'CIM 2023 Theatre.csv'
# 'CIM 2023 Theatre rehearsal studios (Nov 2023).csv'
# 'CIM 2024 Music_Nightclubs.csv'
# 'CIM 2024 Music_Venues_All(1).csv'
# 'CIM 2024 Music_Venues_Grassroots.csv'
#  CNKI-20251104162433678.xls
# 'Colab Notebooks'/
# 'Copy of CV-Xiaorui Yu.docx'
# 'Copy of Official TimelineJS3 Template.gsheet'
# 'Copy of pepsi_choice_ad_2026_03_06-17_14_25.gsheet'
# 'Copy of Untitled spreadsheet.gsheet'
# 'Copy of videolist_Polar Bear Pepsi commercial_search184_2026_02_17.gsheet'
# 'Cover Letter-Xiaorui Yu (1).pdf'
# 'cover letter-Xiaorui Yu.pdf'
# 'Cover Letter-Xiaorui Yu.pdf'
# 'CSF writers who write novels.gsheet'
# 'cultural analysis answers.gsheet'
# 'CV-Xiaorui Yu (1).pdf'
# 'CV Xiaorui Yu.docx'
# 'CV-Xiaorui Yu.docx'
# 'CV-Xiaorui Yu.pdf'
#  data/
# 'data (1).csv'
# 'data (2).csv'
# 'data (3).csv'
# 'data_by_artist (1).csv'
#  data_by_artist.csv
# 'data_by_genres (1).csv'
#  data_by_genres.csv
#  data_by_year.csv
#  data.csv
#  data.gsheet
# 'data_w_genres (1).csv'
#  data_w_genres.csv
#  DiversityInTech.xlsx
#  dse-ml-2026/
# 'English proficency certificate.pdf'
#  exercise-sheet-9-xiaoruiyu405-main/
# 'FINAL-Journey Returning to the West Dissemination and Reception of Chinese Science Fiction in English .docx'
#  final_project_python/
#  fingerprint.gsheet
# 'FOH role responsibilty and expectations.gdoc'
# 'German learning certificate.pdf'
# 'Germany masters.gsheet'
# 'Journey to the West Dissemination and Reception of Chinese Science Fiction in English .gdoc'
# 'KLU_Gästeblatt_ 206113.gdoc'
# 'KLU_Gästeblatt_ 206113.pdf'
#  letter_counts.gsheet
# 'Liejin, List and Russian Name-Listing Poetry.gdoc'
#  london_boroughs_profiles_2015.csv
#  LOVES_LABOURS_LOST_letter_scenes.csv
# '“Marriage and Revolution” in the Lianhuanhua (1950-1980).gdoc'
# 'M.A. transcripts.pdf'
#  mons_cheese_catalogue.csv
# 'mons cheese.gsheet'
# 'motivation letter.gdoc'
#  netflix_cast.csv
#  netflix_countries.csv
#  netflix_genres.csv
# 'netflix screenshot video.mp4'
# 'netflix_titles (1).csv'
# 'netflix_titles (1).gsheet'
#  netflix_titles.csv
#  netflix_titles.gsheet
# 'Original of videolist_Polar Bear Pepsi commercial_search184_2026_02_17.gsheet'
# 'original pepsi_choice_ad_2026_03_06-17_14_25.gsheet'
#  Oscars-demographics-DFE.csv
# 'other reseach proposals (Xiaorui Yu)'/
#  pepsi_2026_search50_2026_03_03-17_22_58.csv
#  pepsi_2026_search50_2026_03_03-17_22_58.gsheet
#  pepsi_search50_2026_03_03-17_13_11.csv
#  pepsi_the_choice_ad_2026_2026_03_06.csv
# 'Personal Statement KCL.gdoc'
#  places_extracted.csv
# 'Project proposal.gdoc'
# 'Proposal Outlining (Xiaorui Yu).gdoc'
# 'pynchon mandarin study in China.gsheet'
# 'reading practice answers.gsheet'
# 'Reference (Prof. Jianhou Ling).gdoc'
#  References.gdoc
#  rotten_tomatoes_top_movies_companies.csv
#  rotten_tomatoes_top_movies_crew.csv
#  rotten_tomatoes_top_movies.csv
#  rotten_tomatoes_top_movies_genres.csv
# 'Saved from Chrome'/
# 'serpapi_alumni_results (1).gsheet'
#  serpapi_alumni_results.csv
#  serpapi_alumni_results.gsheet
# 'Should We Develop AI Generated Literature with Human Ethics.gdoc'
# 'Su Qi referee.gdoc'
# 'Texts - Chinese Science Fiction - Baoshu.tsv'
# 'Texts - Chinese Science Fiction - Cixin LIU .tsv'
# 'Texts - Chinese Science Fiction - CSF female(1) (1).gsheet'
# 'Texts - Chinese Science Fiction - CSF female(1).gsheet'
# 'Texts - Chinese Science Fiction - CSF female(1).tsv'
# 'Texts - Chinese Science Fiction - CSF female.tsv'
# 'Texts - Chinese Science Fiction - Jingfang HAO.tsv'
# 'Texts - Chinese Science Fiction - Qiufan CHEN.tsv'
# 'Texts - Chinese Science Fiction - whole corpus (1).tsv'
# 'Texts - Chinese Science Fiction - whole corpus.tsv'
# 'Texts - Chinese Science Fiction - Xia Jia.tsv'
# 'The Big Data and Mathematical Modeling: (1).gdoc'
# 'The Big Data and Mathematical Modeling:.gdoc'
# 'The Language of Chinese Science Fiction in Translation (Xiaorui Yu).pdf'
# 'The Logical Reverse between ‘Women’s Rights’ and ‘Saving China’ between 1919 and 1926.pdf'
#  THE_MERCHANT_OF_VENICE_letter_scenes.csv
#  THE_MERRY_WIVES_OF_WINDSOR_letter_scenes.csv
# 'The Reversal Relationship between ‘Women’s Rights’ and ‘Saving China’ (1919-1926).docx'
#  THE_TWO_GENTLEMEN_OF_VERONA_letter_scenes.csv
# 'The Visualized Analysis of Sentimental Narrative in the First 80 Chapters of A Dream of Red Mansions.gdoc'
# 'To-do list.gsheet'
# 'token ratio.gsheet'
#  Transcripts.pdf
#  TWELFTH_NIGHT_OR_WHAT_YOU_WILL_letter_scenes.csv
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document.gdoc'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Why is Cixin Liu'\''s The Three-Body Problem appealing as a trilogy?.gdoc'
#  world_bank_indicators_eu_df.gsheet
# 'world_bank_indicators_eu_dict (1).gsheet'
#  world_bank_indicators_eu_dict.gsheet
#  world_bank_indicators_eu_dict.tsv
# 'Writer Poetics: Creation and Criticism.gdoc'
#  xiaohongshurednote-dataset-95528404e08fe9dfedfcdc92a08aba19.csv
#  xiaorui-li-llama-3.1-finetune.ipynb
#  xiaorui-li-mistral-nemo-finetune.ipynb
# 'Xiaorui Yu'/
# 'Xiaorui Yu Cover Letter.gdoc'
# 'Xiaorui Yu GTA CV.gdoc'
#  youtube_tool_experiment.gsheet
#  Yu-Xiaorui-2101211925-11.gdoc
#  Yu-Xiaorui-2101211925-12.docx
#  Yu-Xiaorui-2101211925-9.gdoc
# 'Yu Xiaorui Transcript.pdf'
#  于潇睿+1919-1926年女权话语中“女权”与“救亡”逻辑的倒转.pdf
#  于潇睿-2101211925-量化期末作业.pdf
#  大数据与数学建模——论马修·乔克斯的文学常量分析_于潇睿.pdf
#  广西师大新书推荐.gdoc
#  英文文献综述段落修改.gdoc
# '通过 Chrome 保存'/

# %%
# set dse-ml-2026 as working directory
# %cd dse-ml-2026
# Out:
# /content/drive/MyDrive/dse-ml-2026

# %%
# pull updates from the school repository
# this should be done every morning to ensure you have the latest version of the school materials
# %cd /content/drive/MyDrive/dse-ml-2026/
# !git checkout main

#if you made changes to the notebook, you have to reset the notebook
#this will remove all your changes => save the notebook as a copy
#!git reset --hard


# !git pull
# Out:
# /content/drive/MyDrive/dse-ml-2026
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.

# %% [markdown]
# ### Load a dataset
# You should now be able to load a dataset from your Google Drive

# %%
# look again at the content of your current directory
# you should be in dse-ml-2026 and there should be a sub-folder materials
# %ls
# Out:
# docs/  materials/  README.md

# %%
# move to the correct folder where the dataset is located
# %cd materials/datasets/parlamint
# Out:
# /content/drive/MyDrive/dse-ml-2026/materials/datasets/parlamint

# %%
# import the Pandas library
import pandas as pd
# read in the parlamint data into a Pandas DataFrame object
df = pd.read_csv("parlamint-it-is-2022.txt", sep='\t')
# show the first 5 rows of your dataset
df.head()
# Out:
#                                   ID                      Parent_ID  \
# 0  ParlaMint-IS_2022-01-17-20.seg2.1  ParlaMint-IS_2022-01-17-20.u1
# 1  ParlaMint-IS_2022-01-17-20.seg3.1  ParlaMint-IS_2022-01-17-20.u1
# 2  ParlaMint-IS_2022-01-17-20.seg4.1  ParlaMint-IS_2022-01-17-20.u1
# 3  ParlaMint-IS_2022-01-17-20.seg6.1  ParlaMint-IS_2022-01-17-20.u1
# 4  ParlaMint-IS_2022-01-17-20.seg7.1  ParlaMint-IS_2022-01-17-20.u1
#
#                                                 Text
# 0            President of the United States reports:
# 1  I have decided, according to the proposal of t...
# 2                 Arrange sites, January 11th, 2022.
# 3                    Katrín Jakobsdóttir's daughter.
# 4  Presidential Letters for a meeting of the Gene...
